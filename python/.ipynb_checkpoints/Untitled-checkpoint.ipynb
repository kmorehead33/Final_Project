# %%
import pandas as pd
import numpy as np

# %%
results_db = pd.read_csv("../data/game_data.csv")
results_db.head(10)
# Out:
#   schedule_date  schedule_season schedule_week team_home  score_home  \
# 0     9/10/2015             2015             1        NE          28
# 1     9/13/2015             2015             1       ARI          31
# 2     9/13/2015             2015             1       BUF          27
# 3     9/13/2015             2015             1       CHI          23
# 4     9/13/2015             2015             1       DAL          27
# 5     9/13/2015             2015             1       DEN          19
# 6     9/13/2015             2015             1       HOU          20
# 7     9/13/2015             2015             1       JAX           9
# 8     9/13/2015             2015             1       NYJ          31
# 9     9/13/2015             2015             1       OAK          13
#
#    score_away team_away  spread_favorite  home_win  away_win favorite  \
# 0          21       PIT             -7.0         1         0       NE
# ...

# %%
def underdog_score(game):
    if game['underdog'] == game['team_home']:
        return game['score_home']
    else:
        return game['score_away']

results_db['score_underdog'] = results_db.apply(underdog_score, axis=1)

# %%
def favorite_score(game):
    if game['favorite'] == game['team_home']:
        return game['score_home']
    else:
        return game['score_away']

results_db['score_favorite'] = results_db.apply(favorite_score, axis=1)

# %%
results_db.head(16)
# Out:
#    schedule_date  schedule_season schedule_week team_home  score_home  \
# 0      9/10/2015             2015             1        NE          28
# 1      9/13/2015             2015             1       ARI          31
# 2      9/13/2015             2015             1       BUF          27
# 3      9/13/2015             2015             1       CHI          23
# 4      9/13/2015             2015             1       DAL          27
# 5      9/13/2015             2015             1       DEN          19
# 6      9/13/2015             2015             1       HOU          20
# 7      9/13/2015             2015             1       JAX           9
# 8      9/13/2015             2015             1       NYJ          31
# 9      9/13/2015             2015             1       OAK          13
# 10     9/13/2015             2015             1       LAC          33
# 11     9/13/2015             2015             1       LAR          34
# ...

# %%
#home_score_db = results_db.groupby(['schedule_season', 'team_home', 'schedule_week'])['score_home'].sum()

# %%
#home_score_db = home_score_db.to_frame()

# %%
#home_score_db

# %%
#away_score_db = results_db.groupby(['schedule_season', 'team_away', 'schedule_week'])['score_away'].sum()
#away_score_db = away_score_db.to_frame()

# %%
#away_score_db = away_score_db.rename(columns={'team_away': 'team'})

# %%
#away_score_db

# %%
#merge_score_df = pd.merge(home_score_db, away_score_db, how = 'left', left_on = ['schedule_season', 'team_home', 'schedule_week'], right_on = ['schedule_season', 'team_away', 'schedule_week'])

# %%
scores = {
    "CAR":0,
    "TB":0,
    'ATL':0,
    'NO':0,
    'IND':0,
    'HOU':0,
    'JAX':0,
    'TEN':0,
    'WAS':0,
    'DAL':0,
    'PHI':0,
    'NYG':0,
    'NE':0,
    'NYJ':0,
    'MIA':0,
    'BUF':0,
    'GB':0,
    'CHI':0,
    'MIN':0,
    'DET':0,
    'BAL':0,
    'PIT':0,
    'CLE':0,
    'CIN':0,
    'SF':0,
    'SEA':0,
    'ARI':0,
    'LAR':0,
    'LAC':0,
    'KC':0,
    'DEN':0,
    'OAK':0
}

# %%
for in results_db.itterows():
