# %%
import pandas as pd
import numpy as np

# %%
results_db = pd.read_csv("../data/game_data.csv")
results_db.tail(10)
# Out:
#      schedule_date  schedule_season  schedule_week team_home  score_home  \
# 1052      1/5/2019             2018             18       HOU           7
# 1053      1/6/2019             2018             18       BAL          17
# 1054      1/6/2019             2018             18       CHI          15
# 1055     1/12/2019             2018             19        KC          31
# 1056     1/12/2019             2018             19       LAR          30
# 1057     1/13/2019             2018             19        NE          41
# 1058     1/13/2019             2018             19        NO          20
# 1059     1/20/2019             2018             20        KC          31
# 1060     1/20/2019             2018             20        NO          23
# 1061      2/3/2019             2018             21       LAR           3
#
#       score_away team_away  spread_favorite  home_win  away_win favorite  \
# 1052          21       IND             -2.0         0         1      HOU
# 1053          23       LAC             -3.0         0         1      BAL
# 1054          16       PHI             -6.5         0         1      CHI
# 1055          13       IND             -4.0         1         0       KC
# 1056          22       DAL             -7.5         1         0      LAR
# 1057          28       LAC             -3.5         1         0       NE
# 1058          14       PHI             -8.5         1         0       NO
# 1059          37        NE             -3.0         0         1       KC
# 1060          26       LAR             -3.0         0         1       NO
# 1061          13        NE             -2.0         0         1       NE
#
#      underdog  score_favorite  score_underdog  \
# 1052      IND               0               0
# 1053      LAC               0               0
# 1054      PHI               0               0
# 1055      IND               0               0
# 1056      DAL               0               0
# 1057      LAC               0               0
# 1058      PHI               0             476
# 1059       NE               0               0
# 1060      LAR               0             499
# 1061      LAR               0               0
#
#       season_total_points_for _favorite  season_total_points_against_favorite  \
# 1052                                  0                                     0
# 1053                                  0                                     0
# 1054                                  0                                     0
# 1055                                  0                                     0
# 1056                                  0                                     0
# 1057                                501                                     0
# 1058                                  0                                     0
# 1059                                  0                                     0
# 1060                                  0                                     0
# 1061                                551                                     0
#
#      season_total_points_for _underdog  season_total_points_against_underdog  \
# 1052                                 0                                     0
# 1053                                 0                                     0
# 1054                                 0                                     0
# 1055                                 0                                     0
# 1056                                 0                                     0
# 1057                                 0                                     0
# 1058                                 0                                     0
# 1059                               538                                     0
# 1060                                 0                                     0
# 1061                                 0                                     0
#
#       win_percentage_favorite  win_percentage_underdog
# 1052                        0                        0
# 1053                        0                        0
# 1054                        0                        0
# 1055                        0                        0
# 1056                        0                        0
# 1057                        0                        0
# 1058                        0                        0
# 1059                        0                        0
# 1060                        0                        0
# 1061                        0                        0

# %%
def underdog_score(game):
    if game['underdog'] == game['team_home']:
        return game['score_home']
    else:
        return game['score_away']

results_db['score_underdog'] = results_db.apply(underdog_score, axis=1)

# %%
def favorite_score(game):
    if game['favorite'] == game['team_home']:
        return game['score_home']
    else:
        return game['score_away']

results_db['score_favorite'] = results_db.apply(favorite_score, axis=1)

# %%
season_2015 = results_db['schedule_season'] == 2015
season_2016 = results_db['schedule_season'] == 2016
season_2017 = results_db['schedule_season'] == 2017
season_2018 = results_db['schedule_season'] == 2018

# %%
season_2015_db = results_db[season_2015]
season_2016_db = results_db[season_2016]
season_2017_db = results_db[season_2017]
season_2018_db = results_db[season_2018]

# %%
season_2015_db.tail()
# Out:
#     schedule_date  schedule_season  schedule_week team_home  score_home  \
# 259     1/17/2016             2015             19       CAR          31
# 260     1/17/2016             2015             19       DEN          23
# 261     1/24/2016             2015             20       CAR          49
# 262     1/24/2016             2015             20       DEN          20
# 263      2/7/2016             2015             21       DEN          24
#
#      score_away team_away  spread_favorite  home_win  away_win favorite  \
# 259          24       SEA             -2.5         1         0      CAR
# 260          16       PIT             -7.5         1         0      DEN
# 261          15       ARI             -3.0         1         0      CAR
# 262          18        NE             -3.0         1         0       NE
# 263          10       CAR             -4.5         1         0      CAR
#
#     underdog  score_favorite  score_underdog  \
# 259      SEA              31              24
# 260      PIT              23              16
# 261      ARI              49              15
# 262      DEN              18              20
# 263      DEN              10              24
#
#      season_total_points_for _favorite  season_total_points_against_favorite  \
# 259                                  0                                     0
# 260                                  0                                     0
# 261                                  0                                     0
# 262                                476                                     0
# 263                                  0                                     0
#
#     season_total_points_for _underdog  season_total_points_against_underdog  \
# 259                                 0                                     0
# 260                               457                                     0
# 261                               530                                     0
# 262                                 0                                     0
# 263                                 0                                     0
#
#      win_percentage_favorite  win_percentage_underdog
# 259                        0                        0
# 260                        0                        0
# 261                        0                        0
# 262                        0                        0
# 263                        0                        0

# %%
scores = {
    "CAR":0,
    "TB":0,
    'ATL':0,
    'NO':0,
    'IND':0,
    'HOU':0,
    'JAX':0,
    'TEN':0,
    'WAS':0,
    'DAL':0,
    'PHI':0,
    'NYG':0,
    'NE':0,
    'NYJ':0,
    'MIA':0,
    'BUF':0,
    'GB':0,
    'CHI':0,
    'MIN':0,
    'DET':0,
    'BAL':0,
    'PIT':0,
    'CLE':0,
    'CIN':0,
    'SF':0,
    'SEA':0,
    'ARI':0,
    'LAR':0,
    'LAC':0,
    'KC':0,
    'DEN':0,
    'OAK':0
}

# %%
print(scores)
# Out:
# {'CAR': 0, 'TB': 0, 'ATL': 0, 'NO': 0, 'IND': 0, 'HOU': 0, 'JAX': 0, 'TEN': 0, 'WAS': 0, 'DAL': 0, 'PHI': 0, 'NYG': 0, 'NE': 0, 'NYJ': 0, 'MIA': 0, 'BUF': 0, 'GB': 0, 'CHI': 0, 'MIN': 0, 'DET': 0, 'BAL': 0, 'PIT': 0, 'CLE': 0, 'CIN': 0, 'SF': 0, 'SEA': 0, 'ARI': 0, 'LAR': 0, 'LAC': 0, 'KC': 0, 'DEN': 0, 'OAK': 0}

# %%
week_score_2015 = []
favs_2015 = []
dogs_2015 = []

# %%
line_number=1


current_week = 1
#current_year = 2015
for game in season_2015_db.iterrows():
    #print(game[1])
    if game[1][2] != current_week:
        #print(game[1][4])
        week_score_2015.append(scores.copy())
        current_week = game[1][2]
    scores[game[1][3]]+=game[1][4]
    scores[game[1][6]]+=game[1][5]
    if game[1][2] == 21:
        week_score_2015.append(scores.copy())
        break  

print(len(week_score_2015))
# Out:
# 21

# %%
#print(week_score_2015)

# %%
dict_week = 0 
current_week = 1


for game in season_2015_db.iterrows():
    if game[1][2] != current_week:
        current_week = game[1][2]
        dict_week = dict_week + 1
    favs_2015.append(week_score_2015[dict_week][game[1][10]])
    #favs_2015.append(week_score_2015[dict_week][game[1][12]])
    print(game[1][10])
    dogs_2015.append(week_score_2015[dict_week][game[1][11]])
    #print(game[1][11])
# Out:
# NE
# ARI
# IND
# GB
# DAL
# DEN
# KC
# CAR
# NYJ
# OAK
# LAC
# SEA
# TB
# MIA
# PHI
# MIN
# KC
# BUF
# CAR
# ARI
# CIN
# TEN
# GB
# MIA
# MIN
# NO
# NYG
# BAL
# PHI
# PIT
# LAR
# IND
# NYG
# ARI
# BAL
# CAR
# CLE
# DEN
# HOU
# MIA
# MIN
# NE
# NYJ
# SEA
# LAR
# IND
# GB
# BAL
# ARI
# ATL
# BUF
# OAK
# CIN
# DEN
# IND
# NYJ
# NO
# LAC
# GB
# CAR
# PHI
# SEA
# HOU
# ATL
# BAL
# CIN
# NE
# ARI
# GB
# KC
# NYG
# DEN
# PHI
# TB
# BUF
# LAC
# ATL
# CIN
# DEN
# DET
# GB
# NE
# JAX
# MIN
# NYJ
# ARI
# BAL
# SEA
# TEN
# PHI
# SEA
# CAR
# DET
# IND
# BUF
# KC
# MIA
# NE
# NYG
# LAC
# LAR
# ATL
# WAS
# ARI
# NE
# ATL
# BAL
# MIN
# ARI
# SEA
# GB
# HOU
# DET
# NO
# NYJ
# LAR
# CAR
# CIN
# BUF
# GB
# PHI
# DEN
# MIN
# NE
# NO
# NYJ
# PIT
# ATL
# NYG
# LAC
# NYJ
# BAL
# DEN
# GB
# NE
# OAK
# PHI
# PIT
# SEA
# LAR
# DAL
# CAR
# NO
# CIN
# JAX
# ARI
# ATL
# BAL
# CAR
# DEN
# OAK
# NYJ
# DAL
# PHI
# KC
# SEA
# NE
# CAR
# DET
# GB
# ATL
# CIN
# NE
# HOU
# IND
# JAX
# KC
# NYJ
# ARI
# SEA
# OAK
# NYG
# CLE
# GB
# BUF
# CHI
# CIN
# MIA
# SEA
# NE
# CAR
# NYJ
# KC
# PIT
# DEN
# ARI
# ATL
# TEN
# WAS
# ARI
# SEA
# CAR
# CHI
# CIN
# CLE
# DEN
# GB
# NE
# JAX
# KC
# NYJ
# PHI
# DET
# TB
# NYG
# LAR
# NYJ
# KC
# IND
# JAX
# MIN
# NE
# CAR
# GB
# ARI
# PIT
# LAC
# CIN
# SEA
# BUF
# NO
# OAK
# PHI
# ARI
# CAR
# PIT
# BUF
# DET
# KC
# MIA
# MIN
# NO
# NE
# SEA
# TB
# HOU
# DEN
# ARI
# ATL
# NYJ
# CAR
# DET
# CIN
# PIT
# DAL
# DEN
# GB
# HOU
# IND
# KC
# NE
# NYG
# LAR
# PIT
# KC
# SEA
# WAS
# ARI
# NE
# CAR
# DEN
# CAR
# NE
# CAR

# %%
#print(dogs_2015)

# %%
season_2015_db['season_total_points_for _favorite'] = favs_2015
# Out:
# C:\Users\kylem\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
season_2015_db['season_total_points_for _underdog'] = dogs_2015
# Out:
# C:\Users\kylem\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#2016

# %%
scores = {
    "CAR":0,
    "TB":0,
    'ATL':0,
    'NO':0,
    'IND':0,
    'HOU':0,
    'JAX':0,
    'TEN':0,
    'WAS':0,
    'DAL':0,
    'PHI':0,
    'NYG':0,
    'NE':0,
    'NYJ':0,
    'MIA':0,
    'BUF':0,
    'GB':0,
    'CHI':0,
    'MIN':0,
    'DET':0,
    'BAL':0,
    'PIT':0,
    'CLE':0,
    'CIN':0,
    'SF':0,
    'SEA':0,
    'ARI':0,
    'LAR':0,
    'LAC':0,
    'KC':0,
    'DEN':0,
    'OAK':0
}

# %%
week_score_2016 = []
favs_2016 = []
dogs_2016 = []

# %%
current_week = 1
for game in season_2016_db.iterrows():
    #print(game[1])
    if game[1][2] != current_week:
        #print(game[1][4])
        week_score_2016.append(scores.copy())
        current_week = game[1][2]
    scores[game[1][3]]+=game[1][4]
    scores[game[1][6]]+=game[1][5]
    if game[1][2] == 21:
        week_score_2016.append(scores.copy())
        break

# %%
dict_week = 0 
current_week = 1


for game in season_2016_db.iterrows():
    if game[1][2] != current_week:
        current_week = game[1][2]
        dict_week = dict_week + 1
    favs_2016.append(week_score_2016[dict_week][game[1][10]])
    #favs_2015.append(week_score_2015[dict_week][game[1][12]])
    print(game[1][10])
    dogs_2016.append(week_score_2016[dict_week][game[1][11]])
    #print(game[1][11])
# Out:
# CAR
# ARI
# ATL
# BAL
# NYG
# HOU
# IND
# GB
# KC
# NO
# CIN
# PHI
# SEA
# MIN
# LAR
# PIT
# ARI
# CAR
# BAL
# DEN
# DET
# HOU
# SEA
# GB
# NE
# NYG
# OAK
# PIT
# LAC
# WAS
# CHI
# NE
# ARI
# CAR
# CIN
# DAL
# GB
# IND
# BAL
# KC
# MIA
# NYG
# PIT
# SEA
# TB
# OAK
# NO
# CIN
# ARI
# CAR
# BAL
# DET
# HOU
# IND
# NE
# SEA
# PIT
# LAC
# DAL
# DEN
# WAS
# MIN
# ARI
# BAL
# NE
# CIN
# DEN
# PHI
# GB
# IND
# BUF
# MIA
# MIN
# OAK
# PIT
# CAR
# DEN
# BUF
# CHI
# DET
# GB
# HOU
# PIT
# NE
# CAR
# NYG
# KC
# SEA
# TEN
# PHI
# ARI
# GB
# ARI
# ATL
# CIN
# WAS
# JAX
# KC
# NYG
# BUF
# NYJ
# MIN
# NE
# SF
# TEN
# DEN
# TEN
# ATL
# NE
# CAR
# CIN
# NYJ
# DAL
# DEN
# HOU
# KC
# SEA
# TB
# MIN
# ATL
# PIT
# DAL
# GB
# KC
# CAR
# MIA
# MIN
# NYG
# OAK
# LAC
# NO
# SEA
# BAL
# ARI
# CAR
# JAX
# NE
# NO
# LAR
# PHI
# PIT
# LAC
# CHI
# GB
# WAS
# CAR
# CIN
# PIT
# DAL
# DET
# IND
# KC
# MIA
# MIN
# NYG
# NE
# SEA
# WAS
# OAK
# DAL
# DET
# PIT
# ATL
# BAL
# BUF
# TEN
# NYG
# DEN
# LAC
# MIA
# NO
# NE
# OAK
# SEA
# PHI
# DAL
# ARI
# ATL
# BAL
# SF
# CIN
# GB
# DEN
# NE
# NO
# OAK
# PIT
# LAC
# SEA
# NYJ
# KC
# PIT
# CAR
# CIN
# DET
# SEA
# IND
# MIN
# ATL
# ARI
# DAL
# WAS
# SF
# TB
# TEN
# NE
# SEA
# MIA
# ARI
# ATL
# BAL
# BUF
# GB
# PIT
# DAL
# NE
# HOU
# KC
# MIN
# NYG
# OAK
# WAS
# PHI
# BUF
# ATL
# WAS
# LAC
# GB
# HOU
# TEN
# LAR
# NE
# NO
# OAK
# SEA
# KC
# PIT
# DAL
# ATL
# BAL
# DEN
# GB
# IND
# ARI
# NE
# MIN
# BUF
# PHI
# PIT
# KC
# SEA
# TB
# TEN
# WAS
# HOU
# SEA
# GB
# PIT
# ATL
# NE
# DAL
# KC
# ATL
# NE
# NE

# %%
season_2016_db['season_total_points_for _favorite'] = favs_2016
season_2016_db['season_total_points_for _underdog'] = dogs_2016
# Out:
# C:\Users\kylem\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\kylem\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
season_2016_db.tail()
# Out:
#     schedule_date  schedule_season  schedule_week team_home  score_home  \
# 524     1/15/2017             2016             19       DAL          31
# 525     1/15/2017             2016             19        KC          16
# 526     1/22/2017             2016             20       ATL          44
# 527     1/22/2017             2016             20        NE          36
# 528      2/5/2017             2016             21        NE          34
#
#      score_away team_away  spread_favorite  home_win  away_win favorite  \
# 524          34        GB             -5.5         0         1      DAL
# 525          18       PIT             -2.5         0         1       KC
# 526          21        GB             -6.5         1         0      ATL
# 527          17       PIT             -5.5         1         0       NE
# 528          28       ATL             -3.0         1         0       NE
#
#     underdog  score_favorite  score_underdog  \
# 524       GB              31              34
# 525      PIT              16              18
# 526       GB              44              21
# 527      PIT              36              17
# 528      ATL              34              28
#
#      season_total_points_for _favorite  season_total_points_against_favorite  \
# 524                                452                                     0
# 525                                405                                     0
# 526                                620                                     0
# 527                                511                                     0
# 528                                545                                     0
#
#      season_total_points_for _underdog  season_total_points_against_underdog  \
# 524                                504                                     0
# 525                                447                                     0
# 526                                525                                     0
# 527                                464                                     0
# 528                                648                                     0
#
#      win_percentage_favorite  win_percentage_underdog
# 524                        0                        0
# 525                        0                        0
# 526                        0                        0
# 527                        0                        0
# 528                        0                        0

# %%
print(dogs_2016)
# Out:
# [21, 23, 31, 7, 19, 14, 39, 23, 27, 35, 22, 10, 10, 16, 28, 16, 38, 55, 30, 55, 32, 45, 9, 42, 34, 47, 59, 39, 37, 46, 58, 42, 40, 64, 84, 45, 81, 87, 54, 25, 54, 68, 92, 73, 46, 42, 104, 71, 63, 152, 108, 62, 62, 84, 56, 42, 83, 114, 90, 77, 74, 73, 111, 115, 87, 129, 175, 119, 89, 85, 82, 92, 82, 152, 55, 94, 173, 127, 101, 110, 159, 160, 118, 109, 155, 117, 152, 199, 113, 142, 58, 111, 111, 206, 130, 170, 185, 176, 120, 146, 133, 156, 170, 128, 194, 117, 139, 172, 181, 179, 186, 158, 179, 225, 183, 208, 201, 215, 131, 180, 154, 168, 239, 153, 130, 136, 205, 202, 214, 217, 167, 206, 175, 187, 205, 161, 193, 239, 142, 320, 258, 204, 216, 264, 175, 285, 222, 184, 199, 193, 281, 235, 149, 226, 157, 204, 241, 247, 181, 280, 218, 270, 245, 193, 214, 178, 210, 252, 194, 228, 170, 159, 276, 249, 224, 233, 303, 281, 255, 204, 268, 207, 224, 180, 275, 274, 224, 277, 283, 311, 358, 294, 350, 207, 221, 333, 229, 240, 194, 281, 234, 290, 192, 358, 296, 279, 197, 205, 406, 264, 316, 220, 248, 268, 313, 299, 260, 340, 362, 301, 366, 337, 270, 349, 353, 269, 240, 289, 278, 298, 286, 208, 337, 387, 374, 309, 333, 322, 469, 305, 416, 346, 318, 224, 363, 279, 238, 421, 264, 410, 309, 369, 279, 289, 430, 352, 302, 375, 400, 322, 504, 447, 525, 464, 648]

# %%
#2017

# %%
scores = {
    "CAR":0,
    "TB":0,
    'ATL':0,
    'NO':0,
    'IND':0,
    'HOU':0,
    'JAX':0,
    'TEN':0,
    'WAS':0,
    'DAL':0,
    'PHI':0,
    'NYG':0,
    'NE':0,
    'NYJ':0,
    'MIA':0,
    'BUF':0,
    'GB':0,
    'CHI':0,
    'MIN':0,
    'DET':0,
    'BAL':0,
    'PIT':0,
    'CLE':0,
    'CIN':0,
    'SF':0,
    'SEA':0,
    'ARI':0,
    'LAR':0,
    'LAC':0,
    'KC':0,
    'DEN':0,
    'OAK':0
}

# %%
week_score_2017 = []
favs_2017 = []
dogs_2017 = []

# %%
current_week = 1
for game in season_2017_db.iterrows():
    #print(game[1])
    if game[1][2] != current_week:
        #print(game[1][4])
        week_score_2017.append(scores.copy())
        current_week = game[1][2]
    scores[game[1][3]]+=game[1][4]
    scores[game[1][6]]+=game[1][5]
    if game[1][2] == 21:
        week_score_2017.append(scores.copy())
        break

# %%
dict_week = 0 
current_week = 1


for game in season_2017_db.iterrows():
    if game[1][2] != current_week:
        current_week = game[1][2]
        dict_week = dict_week + 1
    favs_2017.append(week_score_2017[dict_week][game[1][10]])
    #favs_2015.append(week_score_2015[dict_week][game[1][12]])
    print(game[1][10])
    dogs_2017.append(week_score_2017[dict_week][game[1][11]])
    #print(game[1][11])
# Out:
# NE
# BUF
# ATL
# CIN
# PIT
# DAL
# ARI
# GB
# HOU
# IND
# CAR
# TEN
# PHI
# DEN
# MIN
# CIN
# ATL
# BAL
# CAR
# DAL
# ARI
# TEN
# KC
# LAC
# LAR
# NE
# OAK
# PIT
# SEA
# TB
# NYG
# LAR
# DEN
# CAR
# PIT
# ATL
# GB
# CLE
# BAL
# KC
# TB
# NE
# MIA
# PHI
# TEN
# OAK
# DAL
# GB
# ARI
# ATL
# PIT
# CIN
# DAL
# DEN
# TEN
# LAC
# NO
# MIN
# NE
# JAX
# SEA
# TB
# KC
# NE
# CIN
# NYJ
# DAL
# DET
# KC
# IND
# LAR
# TEN
# NYG
# OAK
# PHI
# PIT
# MIN
# CAR
# TB
# ATL
# BAL
# DEN
# HOU
# JAX
# KC
# GB
# NO
# NE
# OAK
# WAS
# TEN
# KC
# BUF
# CAR
# TEN
# NO
# JAX
# DEN
# LAR
# MIA
# MIN
# NE
# SEA
# PIT
# DAL
# PHI
# BAL
# BUF
# CIN
# MIN
# PIT
# NE
# NO
# ATL
# PHI
# SEA
# TB
# DAL
# KC
# BUF
# ATL
# DAL
# HOU
# JAX
# OAK
# NO
# LAR
# PHI
# ARI
# SEA
# TEN
# DET
# SEA
# ATL
# NO
# CHI
# NE
# DET
# PIT
# JAX
# LAR
# NYG
# TB
# TEN
# MIN
# CAR
# PIT
# DET
# JAX
# PHI
# DEN
# BAL
# HOU
# LAC
# TB
# MIN
# NO
# KC
# NE
# SEA
# LAC
# MIN
# WAS
# JAX
# ATL
# CIN
# TEN
# KC
# LAR
# NE
# CAR
# OAK
# PHI
# PIT
# SEA
# BAL
# WAS
# LAR
# ATL
# BAL
# NE
# CHI
# GB
# JAX
# LAC
# DEN
# NO
# KC
# OAK
# PHI
# TEN
# PIT
# ATL
# TEN
# BUF
# MIN
# CIN
# GB
# NYJ
# HOU
# JAX
# KC
# LAC
# LAR
# DAL
# PIT
# NE
# DEN
# DET
# LAC
# BUF
# CAR
# BAL
# JAX
# MIN
# NO
# PHI
# DAL
# NE
# SF
# LAR
# WAS
# ATL
# BAL
# MIN
# ARI
# CAR
# CHI
# DET
# DAL
# KC
# NE
# NO
# LAC
# JAX
# LAR
# WAS
# PIT
# PHI
# ATL
# BAL
# DEN
# DET
# IND
# LAC
# SF
# BUF
# MIN
# NE
# WAS
# DAL
# PIT
# SEA
# NO
# TEN
# KC
# LAR
# JAX
# NO
# NE
# ATL
# MIN
# PIT
# NE
# MIN
# NE

# %%
season_2017_db['season_total_points_for _favorite'] = favs_2017
season_2017_db['season_total_points_for _underdog'] = dogs_2017
# Out:
# C:\Users\kylem\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\kylem\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
season_2017_db.tail()
# Out:
#     schedule_date  schedule_season  schedule_week team_home  score_home  \
# 790     1/14/2018             2017             19       MIN          29
# 791     1/14/2018             2017             19       PIT          42
# 792     1/21/2018             2017             20        NE          24
# 793     1/21/2018             2017             20       PHI          38
# 794      2/4/2018             2017             21        NE          33
#
#      score_away team_away  spread_favorite  home_win  away_win favorite  \
# 790          24        NO             -5.5         1         0      MIN
# 791          45       JAX             -7.0         0         1      PIT
# 792          20       JAX             -7.5         1         0       NE
# 793           7       MIN             -3.0         1         0      MIN
# 794          41       PHI             -4.5         0         1       NE
#
#     underdog  score_favorite  score_underdog  \
# 790       NO              29              24
# 791      JAX              42              45
# 792      JAX              24              20
# 793      PHI               7              38
# 794      PHI              33              41
#
#      season_total_points_for _favorite  season_total_points_against_favorite  \
# 790                                411                                     0
# 791                                448                                     0
# 792                                517                                     0
# 793                                418                                     0
# 794                                550                                     0
#
#      season_total_points_for _underdog  season_total_points_against_underdog  \
# 790                                503                                     0
# 791                                472                                     0
# 792                                492                                     0
# 793                                510                                     0
# 794                                551                                     0
#
#      win_percentage_favorite  win_percentage_underdog
# 790                        0                        0
# 791                        0                        0
# 792                        0                        0
# 793                        0                        0
# 794                        0                        0

# %%
#2018

# %%
scores = {
    "CAR":0,
    "TB":0,
    'ATL':0,
    'NO':0,
    'IND':0,
    'HOU':0,
    'JAX':0,
    'TEN':0,
    'WAS':0,
    'DAL':0,
    'PHI':0,
    'NYG':0,
    'NE':0,
    'NYJ':0,
    'MIA':0,
    'BUF':0,
    'GB':0,
    'CHI':0,
    'MIN':0,
    'DET':0,
    'BAL':0,
    'PIT':0,
    'CLE':0,
    'CIN':0,
    'SF':0,
    'SEA':0,
    'ARI':0,
    'LAR':0,
    'LAC':0,
    'KC':0,
    'DEN':0,
    'OAK':0
}

# %%
week_score_2018 = []
favs_2018 = []
dogs_2018 = []

# %%
current_week = 1
for game in season_2018_db.iterrows():
    #print(game[1])
    if game[1][2] != current_week:
        #print(game[1][4])
        week_score_2018.append(scores.copy())
        current_week = game[1][2]
    scores[game[1][3]]+=game[1][4]
    scores[game[1][6]]+=game[1][5]
    if game[1][2] == 21:
        week_score_2018.append(scores.copy())
        break

# %%
dict_week = 0 
current_week = 1


for game in season_2018_db.iterrows():
    if game[1][2] != current_week:
        current_week = game[1][2]
        dict_week = dict_week + 1
    favs_2018.append(week_score_2018[dict_week][game[1][10]])
    #favs_2015.append(week_score_2015[dict_week][game[1][12]])
    print(game[1][10])
    dogs_2018.append(week_score_2018[dict_week][game[1][11]])
    #print(game[1][11])
# Out:
# PHI
# ARI
# BAL
# CAR
# PIT
# DEN
# GB
# CIN
# LAC
# TEN
# MIN
# NE
# NO
# JAX
# DET
# LAR
# CIN
# ATL
# LAC
# DAL
# DEN
# MIN
# NE
# LAR
# NO
# NYJ
# PIT
# SF
# PHI
# HOU
# WAS
# CHI
# CLE
# CHI
# ATL
# BAL
# CAR
# NE
# HOU
# JAX
# KC
# LAR
# MIA
# MIN
# PHI
# SEA
# GB
# PIT
# LAR
# SEA
# ATL
# CHI
# DAL
# GB
# IND
# JAX
# LAC
# NE
# NO
# OAK
# PIT
# PHI
# KC
# NE
# TEN
# CAR
# CIN
# BAL
# GB
# HOU
# KC
# LAC
# NYJ
# PHI
# PIT
# SF
# LAR
# NO
# PHI
# ATL
# CIN
# CLE
# JAX
# LAR
# HOU
# CHI
# MIN
# NE
# NYJ
# SEA
# BAL
# CAR
# GB
# DEN
# BAL
# NE
# IND
# JAX
# KC
# LAC
# DET
# MIN
# PHI
# LAR
# TB
# DAL
# ATL
# HOU
# ARI
# BAL
# CHI
# CIN
# DET
# PHI
# KC
# LAR
# MIN
# WAS
# IND
# PIT
# NE
# OAK
# BAL
# CHI
# CAR
# KC
# DEN
# MIA
# MIN
# NE
# LAR
# SEA
# WAS
# DAL
# PIT
# CHI
# NO
# ATL
# GB
# IND
# KC
# LAR
# NYJ
# LAC
# PHI
# TB
# NE
# SF
# SEA
# ARI
# ATL
# BAL
# CHI
# CAR
# IND
# PIT
# LAC
# NO
# NYG
# HOU
# LAR
# DAL
# CHI
# NO
# BAL
# JAX
# CAR
# CLE
# PIT
# IND
# LAC
# MIN
# NE
# PHI
# TB
# HOU
# NO
# ATL
# DEN
# LAR
# GB
# HOU
# IND
# MIA
# NE
# CHI
# KC
# PIT
# SEA
# CAR
# TEN
# PHI
# TEN
# DET
# BUF
# LAR
# CAR
# DAL
# GB
# HOU
# KC
# LAC
# NE
# PIT
# DEN
# NO
# NYG
# SEA
# KC
# DEN
# HOU
# ATL
# BAL
# BUF
# CHI
# CIN
# IND
# JAX
# LAR
# MIN
# TEN
# NE
# SEA
# NO
# LAC
# TEN
# LAR
# ATL
# CLE
# DAL
# MIN
# IND
# MIA
# NE
# NO
# GB
# PHI
# CHI
# KC
# DEN
# BAL
# BUF
# LAC
# GB
# HOU
# KC
# LAR
# MIN
# NE
# NO
# NYG
# PIT
# SEA
# ATL
# IND
# PHI
# DAL
# HOU
# BAL
# CHI
# KC
# LAR
# NE
# NO
# KC
# NO
# NE

# %%
season_2018_db['season_total_points_for _favorite'] = favs_2018
season_2018_db['season_total_points_for _underdog'] = dogs_2018
# Out:
# C:\Users\kylem\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\kylem\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
season_2018_db.tail()
# Out:
#      schedule_date  schedule_season  schedule_week team_home  score_home  \
# 1057     1/13/2019             2018             19        NE          41
# 1058     1/13/2019             2018             19        NO          20
# 1059     1/20/2019             2018             20        KC          31
# 1060     1/20/2019             2018             20        NO          23
# 1061      2/3/2019             2018             21       LAR           3
#
#       score_away team_away  spread_favorite  home_win  away_win favorite  \
# 1057          28       LAC             -3.5         1         0       NE
# 1058          14       PHI             -8.5         1         0       NO
# 1059          37        NE             -3.0         0         1       KC
# 1060          26       LAR             -3.0         0         1       NO
# 1061          13        NE             -2.0         0         1       NE
#
#      underdog  score_favorite  score_underdog  \
# 1057      LAC              41              28
# 1058      PHI              20              14
# 1059       NE              31              37
# 1060      LAR              23              26
# 1061      LAR              13               3
#
#       season_total_points_for _favorite  season_total_points_against_favorite  \
# 1057                                477                                     0
# 1058                                524                                     0
# 1059                                627                                     0
# 1060                                547                                     0
# 1061                                527                                     0
#
#       season_total_points_for _underdog  season_total_points_against_underdog  \
# 1057                                479                                     0
# 1058                                397                                     0
# 1059                                514                                     0
# 1060                                583                                     0
# 1061                                586                                     0
#
#       win_percentage_favorite  win_percentage_underdog
# 1057                        0                        0
# 1058                        0                        0
# 1059                        0                        0
# 1060                        0                        0
# 1061                        0                        0

# %%
seasons = [season_2015_db, season_2016_db, season_2017_db, season_2018_db]

# %%
results_db = pd.concat(seasons, sort = False)

# %%
results_db
# Out:
#      schedule_date  schedule_season  schedule_week team_home  score_home  \
# 0        9/10/2015             2015              1        NE          28
# 1        9/13/2015             2015              1       ARI          31
# 2        9/13/2015             2015              1       BUF          27
# 3        9/13/2015             2015              1       CHI          23
# 4        9/13/2015             2015              1       DAL          27
# 5        9/13/2015             2015              1       DEN          19
# 6        9/13/2015             2015              1       HOU          20
# 7        9/13/2015             2015              1       JAX           9
# 8        9/13/2015             2015              1       NYJ          31
# 9        9/13/2015             2015              1       OAK          13
# 10       9/13/2015             2015              1       LAC          33
# 11       9/13/2015             2015              1       LAR          34
# 12       9/13/2015             2015              1        TB          14
# 13       9/13/2015             2015              1       WAS          10
# 14       9/14/2015             2015              1       ATL          26
# 15       9/14/2015             2015              1        SF          20
# 16       9/17/2015             2015              2        KC          24
# 17       9/20/2015             2015              2       BUF          32
# 18       9/20/2015             2015              2       CAR          24
# 19       9/20/2015             2015              2       CHI          23
# 20       9/20/2015             2015              2       CIN          24
# 21       9/20/2015             2015              2       CLE          28
# 22       9/20/2015             2015              2        GB          27
# 23       9/20/2015             2015              2       JAX          23
# 24       9/20/2015             2015              2       MIN          26
# 25       9/20/2015             2015              2        NO          19
# 26       9/20/2015             2015              2       NYG          20
# 27       9/20/2015             2015              2       OAK          37
# 28       9/20/2015             2015              2       PHI          10
# 29       9/20/2015             2015              2       PIT          43
# ...            ...              ...            ...       ...         ...
# 1032    12/23/2018             2018             16        SF           9
# 1033    12/23/2018             2018             16       SEA          38
# 1034    12/24/2018             2018             16       OAK          27
# 1035    12/30/2018             2018             17       BAL          26
# 1036    12/30/2018             2018             17       BUF          42
# 1037    12/30/2018             2018             17       DEN           9
# 1038    12/30/2018             2018             17        GB           0
# 1039    12/30/2018             2018             17       HOU          20
# 1040    12/30/2018             2018             17        KC          35
# 1041    12/30/2018             2018             17       LAR          48
# 1042    12/30/2018             2018             17       MIN          10
# 1043    12/30/2018             2018             17        NE          38
# 1044    12/30/2018             2018             17        NO          14
# 1045    12/30/2018             2018             17       NYG          35
# 1046    12/30/2018             2018             17       PIT          16
# 1047    12/30/2018             2018             17       SEA          27
# 1048    12/30/2018             2018             17        TB          32
# 1049    12/30/2018             2018             17       TEN          17
# 1050    12/30/2018             2018             17       WAS           0
# 1051      1/5/2019             2018             18       DAL          24
# 1052      1/5/2019             2018             18       HOU           7
# 1053      1/6/2019             2018             18       BAL          17
# 1054      1/6/2019             2018             18       CHI          15
# 1055     1/12/2019             2018             19        KC          31
# 1056     1/12/2019             2018             19       LAR          30
# 1057     1/13/2019             2018             19        NE          41
# 1058     1/13/2019             2018             19        NO          20
# 1059     1/20/2019             2018             20        KC          31
# 1060     1/20/2019             2018             20        NO          23
# 1061      2/3/2019             2018             21       LAR           3
#
#       score_away team_away  spread_favorite  home_win  away_win favorite  \
# 0             21       PIT             -7.0         1         0       NE
# 1             19        NO             -2.5         1         0      ARI
# 2             14       IND             -1.0         1         0      IND
# 3             31        GB             -6.5         0         1       GB
# 4             26       NYG             -7.0         1         0      DAL
# 5             13       BAL             -4.5         1         0      DEN
# 6             27        KC             -1.0         0         1       KC
# 7             20       CAR             -3.0         0         1      CAR
# 8             10       CLE             -3.5         1         0      NYJ
# 9             33       CIN             -3.0         0         1      OAK
# 10            28       DET             -3.5         1         0      LAC
# 11            31       SEA             -3.5         1         0      SEA
# 12            42       TEN             -3.0         0         1       TB
# 13            17       MIA             -4.0         0         1      MIA
# 14            24       PHI             -3.0         1         0      PHI
# 15             3       MIN             -2.5         1         0      MIN
# 16            31       DEN             -3.0         0         1       KC
# 17            40        NE             -1.0         0         1      BUF
# 18            17       HOU             -3.0         1         0      CAR
# 19            48       ARI             -2.0         0         1      ARI
# 20            19       LAC             -3.5         1         0      CIN
# 21            14       TEN             -1.0         1         0      TEN
# 22            17       SEA             -3.0         1         0       GB
# 23            20       MIA             -6.0         1         0      MIA
# 24            16       DET             -2.5         1         0      MIN
# 25            26        TB             -9.0         0         1       NO
# 26            24       ATL             -2.0         0         1      NYG
# 27            33       BAL             -6.0         1         0      BAL
# 28            20       DAL             -6.5         0         1      PHI
# 29            18        SF             -6.0         1         0      PIT
# ...          ...       ...              ...       ...       ...      ...
# 1032          14       CHI             -4.0         0         1      CHI
# 1033          31        KC             -1.0         1         0       KC
# 1034          14       DEN             -2.5         1         0      DEN
# 1035          24       CLE             -7.0         1         0      BAL
# 1036          17       MIA             -5.5         1         0      BUF
# 1037          23       LAC             -7.0         0         1      LAC
# 1038          31       DET             -7.5         0         1       GB
# 1039           3       JAX             -7.0         1         0      HOU
# 1040           3       OAK            -14.5         1         0       KC
# 1041          32        SF            -10.5         1         0      LAR
# 1042          24       CHI             -6.0         0         1      MIN
# 1043           3       NYJ            -14.5         1         0       NE
# 1044          33       CAR             -8.0         0         1       NO
# 1045          36       DAL             -7.5         0         1      NYG
# 1046          13       CIN            -14.0         1         0      PIT
# 1047          24       ARI            -14.0         1         0      SEA
# 1048          34       ATL             -2.5         0         1      ATL
# 1049          33       IND             -5.5         0         1      IND
# 1050          24       PHI             -6.0         0         1      PHI
# 1051          22       SEA             -2.5         1         0      DAL
# 1052          21       IND             -2.0         0         1      HOU
# 1053          23       LAC             -3.0         0         1      BAL
# 1054          16       PHI             -6.5         0         1      CHI
# 1055          13       IND             -4.0         1         0       KC
# 1056          22       DAL             -7.5         1         0      LAR
# 1057          28       LAC             -3.5         1         0       NE
# 1058          14       PHI             -8.5         1         0       NO
# 1059          37        NE             -3.0         0         1       KC
# 1060          26       LAR             -3.0         0         1       NO
# 1061          13        NE             -2.0         0         1       NE
#
#      underdog  score_favorite  score_underdog  \
# 0         PIT              28              21
# 1          NO              31              19
# 2         BUF              14              27
# 3         CHI              31              23
# 4         NYG              27              26
# 5         BAL              19              13
# 6         HOU              27              20
# 7         JAX              20               9
# 8         CLE              31              10
# 9         CIN              13              33
# 10        DET              33              28
# 11        LAR              31              34
# 12        TEN              14              42
# 13        WAS              17              10
# 14        ATL              24              26
# 15         SF               3              20
# 16        DEN              24              31
# 17         NE              32              40
# 18        HOU              24              17
# 19        CHI              48              23
# 20        LAC              24              19
# 21        CLE              14              28
# 22        SEA              27              17
# 23        JAX              20              23
# 24        DET              26              16
# 25         TB              19              26
# 26        ATL              20              24
# 27        OAK              33              37
# 28        DAL              10              20
# 29         SF              43              18
# ...       ...             ...             ...
# 1032       SF              14               9
# 1033      SEA              31              38
# 1034      OAK              14              27
# 1035      CLE              26              24
# 1036      MIA              42              17
# 1037      DEN              23               9
# 1038      DET               0              31
# 1039      JAX              20               3
# 1040      OAK              35               3
# 1041       SF              48              32
# 1042      CHI              10              24
# 1043      NYJ              38               3
# 1044      CAR              14              33
# 1045      DAL              35              36
# 1046      CIN              16              13
# 1047      ARI              27              24
# 1048       TB              34              32
# 1049      TEN              33              17
# 1050      WAS              24               0
# 1051      SEA              24              22
# 1052      IND               7              21
# 1053      LAC              17              23
# 1054      PHI              15              16
# 1055      IND              31              13
# 1056      DAL              30              22
# 1057      LAC              41              28
# 1058      PHI              20              14
# 1059       NE              31              37
# 1060      LAR              23              26
# 1061      LAR              13               3
#
#       season_total_points_for _favorite  season_total_points_against_favorite  \
# 0                                    28                                    21
# 1                                    31                                    19
# 2                                    14                                    27
# 3                                    31                                    23
# 4                                    27                                    26
# 5                                    19                                    13
# 6                                    27                                     0
# 7                                    20                                     0
# 8                                    31                                     0
# 9                                    13                                     0
# 10                                   33                                     0
# 11                                   31                                     0
# 12                                   14                                     0
# 13                                   17                                     0
# 14                                   24                                     0
# 15                                    3                                     0
# 16                                   51                                     0
# 17                                   59                                     0
# 18                                   44                                     0
# 19                                   79                                     0
# 20                                   57                                     0
# 21                                   56                                     0
# 22                                   58                                     0
# 23                                   37                                     0
# 24                                   29                                     0
# 25                                   38                                     0
# 26                                   46                                     0
# 27                                   46                                     0
# 28                                   34                                     0
# 29                                   64                                     0
# ...                                 ...                                   ...
# 1032                                397                                     0
# 1033                                530                                     0
# 1034                                320                                     0
# 1035                                389                                     0
# 1036                                269                                     0
# 1037                                428                                     0
# 1038                                376                                     0
# 1039                                402                                     0
# 1040                                565                                     0
# 1041                                527                                     0
# 1042                                360                                     0
# 1043                                436                                     0
# 1044                                504                                     0
# 1045                                369                                     0
# 1046                                428                                     0
# 1047                                428                                     0
# 1048                                414                                     0
# 1049                                433                                     0
# 1050                                367                                     0
# 1051                                363                                     0
# 1052                                409                                     0
# 1053                                406                                     0
# 1054                                436                                     0
# 1055                                596                                     0
# 1056                                557                                     0
# 1057                                477                                     0
# 1058                                524                                     0
# 1059                                627                                     0
# 1060                                547                                     0
# 1061                                527                                     0
#
#       season_total_points_for _underdog  season_total_points_against_underdog  \
# 0                                    21                                    28
# 1                                    19                                    31
# 2                                    27                                    14
# 3                                    23                                    31
# 4                                    26                                    27
# 5                                    13                                    19
# 6                                    20                                     0
# 7                                     9                                     0
# 8                                    10                                     0
# 9                                    33                                     0
# 10                                   28                                     0
# 11                                   34                                     0
# 12                                   42                                     0
# 13                                   10                                     0
# 14                                   26                                     0
# 15                                   20                                     0
# 16                                   50                                     0
# 17                                   68                                     0
# 18                                   37                                     0
# 19                                   46                                     0
# 20                                   52                                     0
# 21                                   38                                     0
# 22                                   48                                     0
# 23                                   32                                     0
# 24                                   44                                     0
# 25                                   40                                     0
# 26                                   50                                     0
# 27                                   50                                     0
# 28                                   47                                     0
# 29                                   38                                     0
# ...                                 ...                                   ...
# 1032                                310                                     0
# 1033                                401                                     0
# 1034                                287                                     0
# 1035                                359                                     0
# 1036                                319                                     0
# 1037                                329                                     0
# 1038                                324                                     0
# 1039                                245                                     0
# 1040                                290                                     0
# 1041                                342                                     0
# 1042                                421                                     0
# 1043                                333                                     0
# 1044                                376                                     0
# 1045                                339                                     0
# 1046                                368                                     0
# 1047                                225                                     0
# 1048                                396                                     0
# 1049                                310                                     0
# 1050                                281                                     0
# 1051                                450                                     0
# 1052                                454                                     0
# 1053                                451                                     0
# 1054                                383                                     0
# 1055                                467                                     0
# 1056                                385                                     0
# 1057                                479                                     0
# 1058                                397                                     0
# 1059                                514                                     0
# 1060                                583                                     0
# 1061                                586                                     0
#
#       win_percentage_favorite  win_percentage_underdog
# 0                           1                        0
# 1                           1                        0
# 2                           0                        1
# 3                           1                        0
# 4                           1                        0
# 5                           1                        0
# 6                           0                        0
# 7                           0                        0
# 8                           0                        0
# 9                           0                        0
# 10                          0                        0
# 11                          0                        0
# 12                          0                        0
# 13                          0                        0
# 14                          0                        0
# 15                          0                        0
# 16                          0                        0
# 17                          0                        0
# 18                          0                        0
# 19                          0                        0
# 20                          0                        0
# 21                          0                        0
# 22                          0                        0
# 23                          0                        0
# 24                          0                        0
# 25                          0                        0
# 26                          0                        0
# 27                          0                        0
# 28                          0                        0
# 29                          0                        0
# ...                       ...                      ...
# 1032                        0                        0
# 1033                        0                        0
# 1034                        0                        0
# 1035                        0                        0
# 1036                        0                        0
# 1037                        0                        0
# 1038                        0                        0
# 1039                        0                        0
# 1040                        0                        0
# 1041                        0                        0
# 1042                        0                        0
# 1043                        0                        0
# 1044                        0                        0
# 1045                        0                        0
# 1046                        0                        0
# 1047                        0                        0
# 1048                        0                        0
# 1049                        0                        0
# 1050                        0                        0
# 1051                        0                        0
# 1052                        0                        0
# 1053                        0                        0
# 1054                        0                        0
# 1055                        0                        0
# 1056                        0                        0
# 1057                        0                        0
# 1058                        0                        0
# 1059                        0                        0
# 1060                        0                        0
# 1061                        0                        0
#
# [1062 rows x 20 columns]
