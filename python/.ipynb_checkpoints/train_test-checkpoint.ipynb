# %%
import pandas as pd

# %%
results_db = pd.read_csv("../data/train_test_data.csv")
results_db.head()
# Out:
#   schedule_date  schedule_season  schedule_week team_home  score_home  \
# 0     9/10/2015             2015              1        NE          28
# 1     9/13/2015             2015              1       ARI          31
# 2     9/13/2015             2015              1       BUF          27
# 3     9/13/2015             2015              1       CHI          23
# 4     9/13/2015             2015              1       DAL          27
#
#    score_away team_away  spread_favorite  home_win  away_win  ... underdog  \
# 0          21       PIT             -7.0         1         0  ...      PIT
# 1          19        NO             -2.5         1         0  ...       NO
# 2          14       IND             -1.0         1         0  ...      BUF
# 3          31        GB             -6.5         0         1  ...      CHI
# 4          26       NYG             -7.0         1         0  ...      NYG
#
#   score_favorite  score_underdog  season_total_points_for _favorite  \
# ...

# %%
results_db = results_db[['favorite', 'underdog', 'spread_favorite', 'season_total_points_for _favorite', 'season_total_points_against_favorite', 'season_total_points_for _underdog', 'season_total_points_against_underdog', 'favorite_win']]

# %%
results_db = results_db.rename(columns={"season_total_points_for _favorite": "season_total_points_favorite", "season_total_points_for _underdog": "season_total_points_underdog"})

# %%
results_db.head()
# Out:
#   favorite underdog  spread_favorite  season_total_points_favorite  \
# 0       NE      PIT             -7.0                            28
# 1      ARI       NO             -2.5                            31
# 2      IND      BUF             -1.0                            14
# 3       GB      CHI             -6.5                            31
# 4      DAL      NYG             -7.0                            27
#
#    season_total_points_against_favorite  season_total_points_underdog  \
# 0                                    21                            21
# 1                                    19                            19
# 2                                    27                            27
# 3                                    23                            23
# 4                                    26                            26
#
#    season_total_points_against_underdog  favorite_win
# 0                                    28             1
# ...
